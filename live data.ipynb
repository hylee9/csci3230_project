# %%
import pandas as pd
import numpy as np
import sqlalchemy
import time
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
engine = sqlalchemy.create_engine('sqlite:///BTCUSDTstreamrandom.db')

# %%
df = pd.read_sql('BTCUSDT', engine)
# df.Price.plot()

# %%
df
# Out:
#      symbol                    Time     Price
# 0   BTCUSDT 2021-12-02 01:26:38.559  57138.79
# 1   BTCUSDT 2021-12-02 01:26:40.564  57145.38
# 2   BTCUSDT 2021-12-02 01:26:42.667  57147.39
# 3   BTCUSDT 2021-12-02 01:26:44.785  57150.26
# 4   BTCUSDT 2021-12-02 01:26:46.884  57154.97
# ..      ...                     ...       ...
# 85  BTCUSDT 2021-12-02 01:35:39.264  57184.39
# 86  BTCUSDT 2021-12-02 01:35:41.316  57160.81
# 87  BTCUSDT 2021-12-02 01:35:43.423  57159.00
# 88  BTCUSDT 2021-12-02 01:35:45.475  57160.79
# 89  BTCUSDT 2021-12-02 01:35:47.699  57156.61
#
# [90 rows x 3 columns]

# %%
x = np.linspace(0, len(df['Price']), len(df['Price']))
y = df['Price']

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()

for i in range(100):
    df = pd.read_sql('BTCUSDT', engine)
    x = np.linspace(0, len(df['Price']), len(df['Price']))
    y = df['Price']
    ax.clear()
    ax.plot(x, y)
    fig.canvas.draw()
    time.sleep(2)
# Out:
# <img src="data:image/png;base64,..." width="640">
